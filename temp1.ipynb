# %%
import cv2
import matplotlib.pyplot as plt
import skimage.transform

# %%
img = cv2.imread('data/data_dhtlp_streaks/images/Light_ASIImg_0.5sec_Bin1_-9.0C_gain0_2022-05-15_000152_frame0041_0.png')

# %%
plt.figure(figsize=(10, 10))
plt.imshow(img)

# %%
im_resized = cv2.resize(img, (512, 512))

# %%
plt.figure(figsize=(10, 10))
plt.imshow(im_resized)

# %%
im_resized2 = skimage.transform.resize(img, (512, 512))
im_resized2.shape
# Out:
# (512, 512, 3)

# %%
plt.figure(figsize=(10, 10))
plt.imshow(im_resized2)
